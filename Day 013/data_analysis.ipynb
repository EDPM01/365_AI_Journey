# %% [markdown]
# # Multivariate Analysis
#
# **Author:** -
#
# **Date:** -
#
# **Description:** - Create Multivariate Analysis, understand relation between variables (aka features)

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## load data

# %%
dataset = pd.read_csv("sleep_data.csv")

# %% [markdown]
# ## dataset information

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Horas_Sueño            100 non-null    float64
#  1   Ejercicio_Minutos      100 non-null    float64
#  2   Cafeina_mg             100 non-null    float64
#  3   Tiempo_Pantalla_Horas  100 non-null    float64
#  4   Calidad_Sueño          100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %% [markdown]
# ## Show first 5

# %%
dataset.head(5)
# Out:
#    Horas_Sueño  Ejercicio_Minutos  Cafeina_mg  Tiempo_Pantalla_Horas  \
# 0     8.399355          44.970152  206.261225               2.663819
# 1     7.924634         -13.443831  178.529723               5.984085
# 2     7.059630          61.325621  206.114875               3.650080
# 3     6.353063          27.906156  227.164901               2.488510
# 4     7.698223          46.622742  202.443004               5.073020
#
#    Calidad_Sueño
# 0       4.906178
# 1       8.073306
# 2       9.371408
# 3       8.437907
# 4       8.992095

# %% [markdown]
# ## Show lasts 5

# %%
dataset.tail(5)
# Out:
#     Horas_Sueño  Ejercicio_Minutos  Cafeina_mg  Tiempo_Pantalla_Horas  \
# 95     6.919283          36.607121  195.055517               4.369361
# 96     7.078635          29.705433  245.953824               1.305747
# 97     5.001799          38.287349  185.486273               2.056772
# 98     7.916328          33.358712  213.369616               6.400828
# 99     7.346488          50.462106  216.084890               2.686211
#
#     Calidad_Sueño
# 95      11.012186
# 96      11.123007
# 97       9.416732
# 98       9.048125
# 99       8.185054

# %% [markdown]
# ## Show descriptive statistics

# %%
dataset.describe()
# Out:
#        Horas_Sueño  Ejercicio_Minutos  Cafeina_mg  Tiempo_Pantalla_Horas  \
# count   100.000000         100.000000  100.000000             100.000000
# mean      7.160174          31.606374  202.282798               3.930186
# std       0.950237          16.632259   50.038566               1.949547
# min       4.151457         -13.443831   92.355470              -1.182085
# 25%       6.564193          18.689364  165.241159               2.680613
# 50%       7.197755          32.857449  202.110079               3.959663
# 75%       7.791329          43.858954  228.049548               5.126361
# max       9.142270          66.596286  328.985467               8.314616
#
#        Calidad_Sueño
# count     100.000000
# mean        7.528815
# std         2.008042
# min         3.067287
# 25%         6.079504
# 50%         7.689991
# 75%         8.858056
# max        12.203366

# %% [markdown]
# ## dataset shape

# %%
dataset.shape
# Out:
# (100, 5)

# %% [markdown]
# ## Show histogram

# %%
# show histogram of whatever column
dataset.Ejercicio_Minutos.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Graphs of variables distribution for each combination

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
pd.plotting.scatter_matrix(dataset, diagonal="kde", figsize=(20,15))
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
cormat = dataset.corr()
cormat
# Out:
#                        Horas_Sueño  Ejercicio_Minutos  Cafeina_mg  \
# Horas_Sueño               1.000000          -0.171165   -0.025039
# Ejercicio_Minutos        -0.171165           1.000000    0.041134
# Cafeina_mg               -0.025039           0.041134    1.000000
# Tiempo_Pantalla_Horas     0.081052           0.002102   -0.019584
# Calidad_Sueño            -0.128585           0.032231    0.121084
#
#                        Tiempo_Pantalla_Horas  Calidad_Sueño
# Horas_Sueño                         0.081052      -0.128585
# Ejercicio_Minutos                   0.002102       0.032231
# Cafeina_mg                         -0.019584       0.121084
# Tiempo_Pantalla_Horas               1.000000      -0.048806
# Calidad_Sueño                      -0.048806       1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cormat, cmap='coolwarm' ,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Notes

# %% [markdown]
# -- Your notes
